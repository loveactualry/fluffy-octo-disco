# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/computation.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.expanding.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.rolling.html

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
s = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2015', periods=1000))
s.plot()

# %%
s = s.cumsum()
s.plot()

# %%
r = s.rolling(window=60)
r
# Out:
# Rolling [window=60,center=False,axis=0]

# %%
r.mean()
# Out:
# 2015-01-01             NaN
# 2015-01-02             NaN
# 2015-01-03             NaN
# 2015-01-04             NaN
# 2015-01-05             NaN
#                   ...
# 2017-09-22   -12651.681770
# 2017-09-23   -12664.987471
# 2017-09-24   -12678.391043
# 2017-09-25   -12691.853156
# 2017-09-26   -12705.337378
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot(style='k--')
r.mean().plot(style='k')

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=pd.date_range('1/1/2000', periods=1000),
                  columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.197105  0.186114 -1.484452  0.418067
# 2000-01-02  0.866424  1.231232 -0.270730 -0.174556
# 2000-01-03 -0.636850 -0.878676  0.028961  0.334624
# 2000-01-04  0.266980  0.875297  0.801118 -0.954207
# 2000-01-05 -0.855736  0.661351  2.539599 -0.451343
# ...              ...       ...       ...       ...
# 2002-09-22  0.453726  0.475753 -0.533389 -0.412837
# 2002-09-23 -0.677323  1.370735 -0.686084 -0.143993
# 2002-09-24  0.170448  0.995161 -0.968036  1.942813
# 2002-09-25  0.241477 -0.767128  1.226801  0.210386
# 2002-09-26  0.347967 -1.839108 -0.330854 -0.133088
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df.plot()

# %%
df.rolling(window=60).sum().plot(subplots=True);

# %%
df.rolling(window=len(df), min_periods=1).mean().plot();

# %%
df.expanding(min_periods=1).mean().plot();

# %%
df.expanding?

# %%
dfe = pd.DataFrame({'B': [0, 1, 2, np.nan, 4]})
dfe.plot()

# %%
dfe.expanding(2).max().plot();
